# %% [markdown]
# <a href="https://colab.research.google.com/github/WeslleyNsou/python/blob/main/Atividade_1_Linguagem_de_programa%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Permite que o usuário insira as notas
nota_1 = float(input("Digite a nota da primeira prova: "))
nota_2 = float(input("Digite a nota da segunda prova: "))
nota_3 = float(input("Digite a nota da terceira prova: "))

print(f"nota 1: {nota_1}")
print(f"nota 2: {nota_2}")
print(f"nota 3: {nota_3}")
# Out:
# Digite a nota da primeira prova: 5
# Digite a nota da segunda prova: 6
# Digite a nota da terceira prova: 7
# nota 1: 5.0
# nota 2: 6.0
# nota 3: 7.0

# %%
#As notas são armazenadas na lista notas
notas = [nota_1, nota_2, nota_3]
notas
# Out:
# [5.0, 6.0, 7.0]

# %%
#O for e utilizado para somar as notas da lista
soma = 0
for nota in notas:
    soma += nota
print(soma)
# Out:
# 18.0

# %%
#Define a media
media = soma / len(notas)
print(f"Média: {media}")
# Out:
# Média: 6.0

# %%
#Define a situação do aluno
if media >= 7 :
  situacao = "Aprovado"
else:
  situacao = "Reprovado"
print(f"Situação: {situacao}")
# Out:
# Situação: Reprovado

# %%
#Exibe os resultados
print("--NOTAS--")
print(f"notas 1: {nota_1}")
print(f"notas 2: {nota_2}")
print(f"notas 3: {nota_3}")

print("--RESULTADOS--")
print(f"Média: {media}")
print(f"Situação: {situacao}")
# Out:
# --NOTAS--
# notas 1: 5.0
# notas 2: 6.0
# notas 3: 7.0
# --RESULTADOS--
# Média: 6.0
# Situação: Reprovado
