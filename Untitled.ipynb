# %% [markdown]
# <a href="https://colab.research.google.com/github/WeslleyNsou/python/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello word!")
# Out:
# Hello word!

# %%
nome = input("Digite seu nome:")

print(nome)

#formatadores de caracteres
print("Olá %s, parabens pelo seu primeiro hello word!" % (nome))

#f-string
print(f"Olá {nome}, parabens pelo seu primeiro hello word!")
# Out:
# Digite seu nome:Wesley
# Wesley
# Olá Wesley, parabens pelo seu primeiro hello word!
# Olá Wesley, parabens pelo seu primeiro hello word!
